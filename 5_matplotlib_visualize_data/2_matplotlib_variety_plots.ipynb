# %%
import matplotlib as mpl
import matplotlib.pylab as plt

# %%
import pandas as pd
import numpy as np

# %%
# matplotlib 한글 표시 설정
import matplotlib.font_manager as fm

# matplotlib의 글꼴 관리자에 특정 글꼴 추가 
fe = fm.FontEntry(
    fname=r'font/NanumGothic.ttf',
    name='NanumGothic'
)
fm.fontManager.ttflist.insert(0,fe)

# pyplot에 matplotlib의 글꼴 관리자에 등록된 글꼴 적용
plt.rcParams.update({'font.family':'NanumGothic','font.size':14})
# pyplot에서 '-'를 문자로 취급하도록 설정
plt.rcParams['axes.unicode_minus']=False

# %% [markdown]
# ### 바 차트 (막대 그래프)
# x 축의 값이 분류가 가능한 카테고리 형태일 때 `bar()`, `barh()` 메서드로 막대 그래프를 표시할 수 있음
# 주의! pyplot의 plot 메서드와는 다르게 bar 메서드는 x축의 값이 첫 번째 인수로 옴

# %%
y = [2, 3, 1]
x = [1, 2, 3]
xlabel = ['가', '나', '다']

plt.bar(x, y)
plt.xticks(x, xlabel)
plt.yticks(sorted(y))
plt.show()

# %% [markdown]
# `xerr`, `yerr` 인수를 지정하면 에러 바를 추가할 수 있음
# `alpha` 인수를 지정하면 바의 투명도를 지정할 수 있음 (0: 완전 투명, 1: 완전 불투명)

# %%
np.random.seed(0)

poeple = ['몽룡', '춘향', '방자', '향단']
y_position = np.arange(4)
y_performance = 3 + 10 * np.random.rand(4)
error = np.random.rand(4)

plt.title('Bar h')
plt.barh(y_position, y_performance, xerr=error, alpha=0.4)
plt.yticks(y_position, poeple)
plt.xlabel('x 축')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 스템 플롯
# 이산확률이나 자기 상관관계를 표현하고자 할 때 사용하는 차트
# `stem()` 메서드로 표시할 수 있음

# %%
x = np.linspace(0.1, 2 * np.pi, 10)
plt.title('스템 플롯')
plt.stem(x, np.cos(x), '-.')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 파이 차트
# 각 분류가 전체에서 얼만큼 차지하고 있는지 파악하려 할때 사용하는 차트
# `pie()` 메서드로 표현할 수 있음
# 주의! 차트가 원형태를 유지할 수 있게 하려면 `axis('equal')`을 지정해야 함

# %%
labels = ['개구리', '돼지', '개', '고양이']
sizes = [15, 30, 45, 10]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
# 띄어짐
explode = (0, 0, 0.1, 0)

plt.title('파이 차트')
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')
plt.show()

# %% [markdown]
# ### 히스토그램
# 특정 구간을 정하여 그 구간에 대한 집계 데이터를 표시할 때 사용하는 차트
# `hist()` 메서드로 표시할 수 있음
# `bins()` 인수로 집계할 구간의 정보를 받음

# %%
x = np.random.randn(1000)
plt.title('히스토그램')
arrays, bins, patches = plt.hist(x, bins=10)
plt.grid(True)
plt.show()

# %%
arrays
# Out:
# array([  6.,  22.,  88., 177., 247., 229., 134.,  73.,  20.,   4.])

# %%
bins
# Out:
# array([-2.99461286, -2.3780541 , -1.76149533, -1.14493657, -0.52837781,
#         0.08818096,  0.70473972,  1.32129848,  1.93785725,  2.55441601,
#         3.17097477])

# %%
patches
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ### 스캐터 플롯
# 두 변수 간의 상관관계를 나타내고자 할 때 사용하는 차트
# `scatter()` 메서드로 표현할 수 있음
# 점 하나의 위치는 x, y 값으로 표현됨

# %%
x = np.random.normal(0, 1, 100)
y = np.random.normal(0, 1, 100)

plt.title('스캐터 플롯')
plt.scatter(x, y)
plt.grid(True)
plt.show()

# %% [markdown]
# 만약 x에 대하여 여러 변수를 한 차트로 비교하고자 할 때 점의 크기 혹은 색상으로 추가로 표현할 수 있음
# `scatter()` 메서드의 `c` 인수로 색상을, `s` 인수로 크기를 지정할 수 있음

# %%
n = 30
x = np.random.rand(n)
y1 = np.random.rand(n)
y2 = np.random.rand(n)
y3 = np.pi * (15 * np.random.rand(n)) ** 2

plt.title('버블 차트')
plt.scatter(x, y1, c=y2, s=y3)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Imshow
# 이미지 데이터처럼 행과 열을 가진 2차원 데이터에 대하여 각 행렬 값을 색으로 표현하는 차트
# `imshow()` 메서드로 표현할 수 있음

# %%
# pip install scikit-learn
from sklearn.datasets import load_digits

# %%
digits = load_digits()
x = digits.images[0]
x
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
plt.title('mnist digists; 0')
plt.imshow(x, interpolation='nearest', cmap=plt.cm.bone_r)
# 사이즈 조절
plt.subplots_adjust(left=0.35, right=0.65, bottom=0.35, top=0.65)
y1 = np.random.rand(n)
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# `cmap` 인수로 데이터를 표현하는 칼라맵을 지정할 수 있음
# `interpolation` 인수로 데이터의 시각화 표현을 지정할 수 있음

# %%
figure, axes = plt.subplots(1, 4, figsize=(12, 3), subplot_kw={'xticks':[],'yticks':[]})

axes[0].set_title('color map Blues')
axes[0].imshow(x, interpolation='nearest', cmap=plt.cm.Blues)
axes[1].set_title('color map Blues_r')
axes[1].imshow(x, interpolation='nearest', cmap=plt.cm.bone_r)
axes[2].set_title('interpolation none')
axes[2].imshow(x, interpolation='none', cmap=plt.cm.bone_r)
axes[3].set_title('color map Blues')
axes[3].imshow(x, interpolation='kaiser', cmap=plt.cm.bone_r)

plt.show()

# %% [markdown]
# ### 컨투어 플롯
# 3차원 자료에서 x, y 입력과 z 출력이 존재할 때, z 표현을 명암이 아닌 선을 사용하는 방법
# `contour()`, `contourf()` 메서드를 사용
# `contour()` : 등고선만 표시 / `contourf()` : 색으로 표시
# 입력 x, y에 대하여 1차원 배열을 그대로 사용할 수 없고, `meshgrid()` 메서드로 포인트 행렬을 만들어 사용해야 함

# %%
def f(x, y):
    return(1 - x / 2 + x ** 5 + y ** 3) * np.exp(-x ** 2 - y ** 2)

n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
xx, yy = np.meshgrid(x, y)
zz = f(xx, yy)

plt.title('컨투어 플롯')
plt.contour(xx, yy, colors='black')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 11
#       8 zz = f(xx, yy)
#      10 plt.title('컨투어 플롯')
# ---> 11 plt.contour(xx, yy, colors='black')
#      12 plt.grid(True)
#      13 plt.show()
#
# File c:\Users\ITPS\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:2939, in contour(data, *args, **kwargs)
#    2937 @_copy_docstring_and_deprecators(Axes.contour)
#    2938 def contour(*args, data=None, **kwargs) -> QuadContourSet:
# -> 2939     __ret = gca().contour(
#    2940         *args, **({"data": data} if data is not None else {}), **kwargs
#    2941     )
#    2942     if __ret._A is not None:  # type: ignore[attr-defined]
#    2943         sci(__ret)
#
# File c:\Users\ITPS\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# File c:\Users\ITPS\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_axes.py:6520, in Axes.contour(self, *args, **kwargs)
#    6511 """
#    6512 Plot contour lines.
#    6513
#    (...)
#    6517 %(contour_doc)s
#    6518 """
#    6519 kwargs['filled'] = False
# -> 6520 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6521 self._request_autoscale_view()
#    6522 return contours
#
# File c:\Users\ITPS\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\contour.py:858, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     854 if self.negative_linestyles is None:
#     855     self.negative_linestyles = \
#     856         mpl.rcParams['contour.negative_linestyle']
# --> 858 kwargs = self._process_args(*args, **kwargs)
#     859 self._process_levels()
#     861 self._extend_min = self.extend in ['min', 'both']
#
# File c:\Users\ITPS\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\contour.py:1523, in QuadContourSet._process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1520         corner_mask = mpl.rcParams['contour.corner_mask']
#    1521 self._corner_mask = corner_mask
# -> 1523 x, y, z = self._contour_args(args, kwargs)
#    1525 contour_generator = contourpy.contour_generator(
#    1526     x, y, z, name=self._algorithm, corner_mask=self._corner_mask,
#    1527     line_type=contourpy.LineType.SeparateCode,
#    1528     fill_type=contourpy.FillType.OuterCode,
#    1529     chunk_size=self.nchunk)
#    1531 t = self.get_transform()
#
# File c:\Users\ITPS\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\contour.py:1574, in QuadContourSet._contour_args(self, args, kwargs)
#    1572     _api.warn_external('Log scale: values of z <= 0 have been masked')
#    1573     self.zmin = z.min().astype(float)
# -> 1574 self._process_contour_level_args(args, z.dtype)
#    1575 return (x, y, z)
#
# File c:\Users\ITPS\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\contour.py:1238, in ContourSet._process_contour_level_args(self, args, z_dtype)
#    1236     raise ValueError("Filled contours require at least 2 levels.")
#    1237 if len(self.levels) > 1 and np.min(np.diff(self.levels)) <= 0.0:
# -> 1238     raise ValueError("Contour levels must be increasing")
#
# ValueError: Contour levels must be increasing

# %%
def f(x, y):
    return (1 - x / 2 + x ** 5 + y ** 3) * np.exp(-x ** 2 - y ** 2)

n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
xx, yy = np.meshgrid(x, y)
zz = f(xx, yy)

plt.title('컨투어 플롯')
plt.contour(xx, yy, zz, colors='black')
plt.contourf(xx, yy, zz, alpha=0.75, cmap='jet')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 3D 서피스 플롯
# 3차원 데이터를 입체적으로 표현하는 차트
# 3d Axes 객체를 생성하여 사용함
# `plot_wireframe()`, `plot_surface()` 메서드로 표현

# %%
x = np.arange(-4, 4, 0.25)
y = np.arange(-4, 4, 0.25)
xx, yy = np.meshgrid(x, y)
rr = np.sqrt(xx**2 + yy**2)
zz = np.sin(rr)

axes = plt.axes(projection='3d')
axes.set_title('3D 서피드 플롯')
axes.plot_surface(xx, yy, zz, rstride=1, cstride=1, cmap='hot')
plt.show()

# %% [markdown]
# ### 삼각 그리드
# 사각형 영역 뿐 아니라 임의 영역에서도 각종 차트를 그릴 수 있어서 정의역이 직사각형이 아닌 2차원 함수도 시각화 할 수 있음
# matplotlib에서 삼각 그리드를 사용할 땐 tri 하위 패키지를 사용
# ```python
# import matplotlib.tri as mtri
# ```

# %%
import matplotlib.tri as mtri

# %% [markdown]
# ### 삼각 그리드 생성
# `Triangulation` 클래스로 삼각 그리드를 생성할 수 있음
# `Triangulation` 클래스의 생성자는 x, y, triangles 세 개의 인수를 받음
# `triangles` 는 각 점의 기하학적 위상 정보

# %%
x = np.array([0, 1, 2])
y = np.array([0, np.sqrt(3), 0])
triangles = [[0, 1, 2]]
triangle = mtri.Triangulation(x, y, triangles)

plt.title('삼각 그리드')
plt.triplot(triangle, 'ko-')
plt.xlim(-0.1, 2.1)
plt.ylim(-0.1, 1.8)
plt.grid(True)
plt.show()

# %%
x = np.asarray([0, 1, 2, 3, 4, 2])
y = np.asarray([0, np.sqrt(3), 0, np.sqrt(3), 0, 2 * np.sqrt(3)])
triangles = [[0, 1, 2], [2, 3, 4], [1, 2, 3], [1, 3, 5]]
triangle = mtri.Triangulation(x, y, triangles)

plt.title('여러 개 삼각형 그리드')
plt.triplot(triangle, 'ko-')
plt.xlim(-0.1, 4.1)
plt.ylim(-0.1, 3.7)
plt.grid(True)
plt.show()

# %% [markdown]
# ### 삼각 그리드 세분화
# `TriRefiner`, `UniformTriRefiner` 클래스로 그리드를 세분화 할 수 있음
# `refiner_triangulation()` : 단순히 삼각 그리드를 세분화
# `refine_field()` : 실제 함수에 최적화된 삼각 그리드 생성

# %%
refiner = mtri.UniformTriRefiner(triangle)
triangle2 = refiner.refine_triangulation(subdiv=2)

plt.title('삼각 그리드 세분화')
plt.triplot(triangle2, 'ko-')
plt.xlim(-0.1, 4.1)
plt.ylim(-0.1, 3.7)
plt.grid(True)
plt.show()

# %% [markdown]
# ### 삼각 그리드 플롯
# 삼차원 그리드 상에 `tricontour`, `tricontourf`, `plot_trisur`, `plot_trisurf` 를 사용하여
# 2차원 등고선이나 3차원 표면을 그릴 수 있음

# %%
triangle3 = refiner.refine_triangulation(subdiv=5)
z = np.cos(1.5 * triangle3.x) * np.cos(1.5 * triangle3.y)

plt.title('삼각 그리드 등고선')
plt.tricontourf(triangle3, z, cmap='jet')
plt.grid(True)
plt.show()

# %%
triangle4 = refiner.refine_triangulation(subdiv=3)
z = np.cos(1.5 * triangle4.x) * np.cos(1.5 * triangle4.y)

axes = plt.axes(projection='3d')
axes.set_title('삼각 그리드 3차원')
axes.plot_trisurf(triangle4.x, triangle4.y, z, cmap=mpl.jet, linewidth=0.2)
axes.tricontourf(triangle4, z, )
axes.set_zlim(-1, 1)
# 앞 숫자 위아래 방향, 뒤 숫자 좌우 방향
axes.view_init(40, -40)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 6
#       4 axes = plt.axes(projection='3d')
#       5 axes.set_title('삼각 그리드 3차원')
# ----> 6 axes.plot_trisurf(triangle4.x, triangle4.y, z, cmap=mpl.jet, linewidth=0.2)
#       7 axes.set_zlim(-1, 1)
#       8 # 앞 숫자 위아래 방향, 뒤 숫자 좌우 방향
#
# File c:\Users\ITPS\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\_api\__init__.py:217, in caching_module_getattr.<locals>.__getattr__(name)
#     215 if name in props:
#     216     return props[name].__get__(instance)
# --> 217 raise AttributeError(
#     218     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'jet'
